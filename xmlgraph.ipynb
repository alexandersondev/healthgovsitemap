# %%
from bigtree import list_to_tree, tree_to_dict, tree_to_dot, tree_to_dataframe, dataframe_to_tree
from bigtree import Node as Bnode
import pydot

# %%
from lxml import etree
import requests

xml_dict = {}

r = requests.get("https://health.gov/sitemap.xml?page=2")
root = etree.fromstring(r.content)
print(f"The number of sitemap tags are {len(root)}")
for sitemap in root:
    children = sitemap.getchildren()
    xml_dict[children[0].text] = children[1].text
for key in xml_dict.keys():
    #print(key, xml_dict[key])
    pass
# Out:
# The number of sitemap tags are 524

# %%
#create directory tree
#start with getting links
link_array = [i for i in xml_dict]

# %%
class URLNode:
    def __init__(self, name, nodeid):
        self.name = name
        self.children = []
        self.nodeid = nodeid
    #for readability
    def get_link_text():
        return self.name
    
    def __repr__(self):
        return self.name
    
    def add_child(self, child_node):
        return self.children.append(child_node)
    
    def print_tree(self, level=0):
        print('\t' * level + repr(self.name))
        for child in self.children:
            child.print_tree(level + 1)
#links are later, for webcrawling pages and then seeing if they link to any other pages
#not necessarily representative of website structure so something to discuss in the meeting

# %%
def root_to_bigtree(root):
    if type(root) == URLNode:
        big_node = Bnode(root.name)
    elif type(root)== etree._Element:
        print('element node!')
        print(root.base)
        big_node = Bnode(root.text)
    else:
        big_node = Bnode(root.val)
    big_children = []
    for child in root.children:
        big_children.append(root_to_bigtree(child))
    big_node.children = big_children
    return big_node

# %%
def build_tree_from_urls(urls):
    root = URLNode("/", nodeid= 0)
    i = 1
    
    for url in sorted(urls):
        parts = url.split("/")
        current_node = root

        for part in parts:
            if part:
                found = False
                for child in current_node.children:
                    if child.name == part:
                        current_node = child
                        found = True
                        break
                
                if not found:
                    if current_node.nodeid == 0:
                        new_node = URLNode(part, nodeid=i)
                        current_node.add_child(new_node)
                        current_node = new_node
                    else:
                        new_node = URLNode(part, nodeid=i+1)
                        current_node.add_child(new_node)
                        current_node = new_node  

    return root

# %%
def print_tree(node, indent="├"):
    if node.nodeid != 0:
        print(node.name)
        

    for child in node.children:
        print_tree(child, indent + "────")

# %%
root = build_tree_from_urls(link_array)

# %%
big_root = build_tree_from_urls(link_array)

# %%
type(root.children[0].children[0])
# Out:
# __main__.URLNode

# %%
root.print_tree()
# Out:
# '/'
# 	'https:'
# 		'health.gov'
# 			'about-odphp'
# 				'committees-workgroups'
# 					'national-clinical-care-commission'
# 						'meetings'
# 							'meeting-1'
# 								'meeting-1-agenda'
# 							'meeting-4'
# 								'meeting-4-agenda'
# 							'meeting-5'
# 								'meeting-5-agenda'
# 							'meeting-6'
# 								'meeting-6-agenda'
# 							'meeting-7'
# 								'meeting-7-agenda'
# 							'meeting-8'
# 								'meeting-8-agenda'
# 							'nccc-meeting-10'
# 								'nccc-meeting-10-agenda'
# 							'nccc-meeting-11'
# 								'nccc-meeting-11-agenda'
# 							'nccc-meeting-12'
# 								'nccc-meeting-12-agenda'
# 							'nccc-meeting-9'
# 								'nccc-meeting-9-agenda'
# 						'report-congress'
# 				'contact-us'
# 					'speaker-request-form'
# 				'our-director'
# 				'previous-initiatives'
# 				'quality-guidelines'
# 					'linking-policy'
# 			'espanol'
# 				'moveyourway'
# 					'stories'
# 						'cheryl'
# 						'jeff'
# 						'john-patty'
# 						'joni'
# 						'nikia'
# 						'rodriguez-family'
# 					'widget'
# 				'myhealthfinder'
# 					'embarazo'
# 						'consultas-doctor-o-partera'
# 							'amamanta-tu-bebe'
# 							'habla-doctor-pruebas-deteccion-necesitan-recien-nacidos'
# 							'ten-embarazo-saludable'
# 						'nutricion-actividad-fisica'
# 							'alimentate-saludablemente-embarazo-consejos-rapidos'
# 							'alimentate-saludablemente-mientras-amamantas-consejos-rapidos'
# 							'mantente-activa-embarazo-consejos-rapidos'
# 					'llevar-vida-sana'
# 						'precauciones-seguridad'
# 							'toma-medicamentos-forma-segura'
# 						'salud-mental-relaciones-otras-personas'
# 							'consumo-indebido-drogas-iniciar-conversacion'
# 							'presta-atencion-senales-alerta-violencia-relacion-pareja'
# 						'salud-sexual'
# 							'realiza-tu-visita-control-mujer-sana-todos-anos'
# 					'problemas-salud'
# 						'cancer'
# 							'dejar-fumar-iniciar-conversacion'
# 							'hable-medico-si-su-familia-hay-historial-cancer-seno-o-ovario'
# 							'hagase-prueba-detectar-cancer-seno'
# 							'prueba-deteccion-temprana-cancer-colorrectal-iniciar-conversacion'
# 							'prueba-deteccion-temprana-cancer-prostata-preguntas-medico'
# 							'tome-medidas-prevenir-cancer-piel'
# 						'diabetes'
# 							'alimentacion-saludable-iniciar-conversacion'
# 							'alimentate-saludablemente'
# 							'ayuda-ser-querido-ser-activo-consejos-rapidos'
# 							'bajar-peso-iniciar-conversacion'
# 							'deja-fumar'
# 							'manten-peso-saludable'
# 							'mantente-activo-fisicamente'
# 							'toma-medidas-prevenir-diabetes-tipo-2'
# 						'infeccion-vih-otras-enfermedades-transmision-sexual'
# 							'habla-tu-hijo-adolescente-prevenir-enfermedades-transmision-sexual'
# 							'hazte-prueba-vih'
# 							'hazte-pruebas-detectar-clamidia-gonorrea'
# 							'protegete-hepatitis-b'
# 							'prueba-sifilis-preguntas-doctor'
# 							'prueba-vih-preguntas-doctor'
# 							'pruebas-detectar-infecciones-transmision-sexual-iniciar-conversacion'
# 						'obesidad'
# 							'ayuda-tu-hijo-o-hija-mantenerse-peso-saludable'
# 							'bajar-peso-preguntas-doctor'
# 							'mantente-activo-paso-anos-consejos-rapidos'
# 							'mantente-activo-si-tienes-discapacidad-consejos-rapidos'
# 						'salud-corazon'
# 							'alimentos-menos-sodio-sal-lista-compras'
# 							'alimentos-tener-corazon-sano-lista-compras'
# 							'consume-menos-sodio-consejos-rapidos'
# 							'controla-estres'
# 							'habla-doctor-acerca-tomar-aspirina-prevenir-enfermedades'
# 							'habla-tu-doctor-aneurisma-aortico-abdominal'
# 							'manten-sano-tu-corazon'
# 							'reduzca-su-riesgo-tener-derrame-cerebral'
# 							'salud-corazon-iniciar-conversacion'
# 							'si-tomas-alcohol-hazlo-moderacion'
# 					'temas'
# 						'embarazo'
# 							'nutricion-y-actividad-fisica'
# 								'toma-suficiente-acido-folico'
# 					'visitas-doctor'
# 						'charlas-doctor'
# 							'mamografias-preguntas-medico'
# 							'medicamentos-prevenir-ataque-corazon-derrame-cerebral-preguntas-doctor'
# 							'prevenir-osteoporosis-preguntas-doctor'
# 							'previniendo-diabetes-tipo-2-preguntas-doctor'
# 							'previniendo-preeclampsia-preguntas-doctor'
# 							'prueba-deteccion-diabetes-gestacional-preguntas-doctor'
# 							'prueba-deteccion-hepatitis-c-preguntas-doctor'
# 							'prueba-deteccion-temprana-cancer-colorrectal-preguntas-doctor'
# 							'prueba-deteccion-temprana-cancer-pulmon-preguntas-doctor'
# 							'pruebas-geneticas-saber-riesgo-corre-desarrollar-cancer-seno-ovario-preguntas-medico'
# 							'toma-control-cuidado-tu-salud'
# 						'chequeos-periodicos'
# 							'cuida-dientes-tus-hijos'
# 							'escoger-doctor-consejos-rapidos'
# 							'haz-tu-visita-bienestar-medicare-todos-anos'
# 							'hombres-tomen-control-su-salud'
# 							'saca-mayor-provecho-visita-tu-bebe-doctor-nacimiento-11-meses-edad'
# 							'saca-mayor-provecho-visita-tus-hijos-adolescentes-doctor-15-17-anos-edad'
# 							'saca-mayor-provecho-visita-tus-hijos-doctor-11-14-anos-edad'
# 							'saca-mayor-provecho-visita-tus-hijos-doctor-5-10-anos-edad'
# 							'saca-mayor-provecho-visitas-tu-hijo-doctor-1-4-anos-edad'
# 							'salud-boca-personas-mayores-consejos-rapidos'
# 						'pruebas-deteccion'
# 							'habla-tu-doctor-ansiedad'
# 							'habla-tu-doctor-depresion'
# 							'hagase-pruebas-deteccion-temprana-cancer-colorrectal'
# 							'hazte-prueba-colesterol'
# 							'hazte-prueba-densidad-huesos'
# 							'hazte-prueba-deteccion-cancer-cuello-uterino'
# 							'hazte-pruebas-deteccion-temprana'
# 							'hazte-tomar-presion-arterial'
# 							'lleva-tus-hijos-examinen-ojos'
# 							'prueba-tuberculosis-latente-preguntas-doctor'
# 						'vacunas'
# 							'asegurate-tus-hijos-esten-dia-vacunas'
# 							'asegurate-tus-hijos-preadolescentes-esten-dia-vacunas'
# 							'protegete-gripe-influenza-estacional'
# 							'vacuna-tus-hijos-vph'
# 							'vacunate-proteger-tu-salud-adultos-19-49-anos-edad'
# 							'vacunate-proteger-tu-salud-personas-adultas-50-anos-o'
# 					'viviendo-sanamente'
# 						'actividad-fisica'
# 							'protege-tu-salud-medida-envejeces'
# 						'nutricion'
# 							'calcio-lista-compras'
# 							'consume-suficiente-calcio'
# 							'meriendas-o-refrigerios-saludables-consejos-rapidos-padres'
# 						'precauciones-seguridad'
# 							'prevencion-caidas-iniciar-conversacion'
# 							'prevenir-dolor-espalda'
# 							'prevenir-infecciones-cuando-recibes-atencion-medica'
# 							'reduce-riesgo-sufrir-caidas'
# 						'salud-mental-relaciones-otras-personas'
# 							'ansiedad-iniciar-conversacion'
# 							'apoya-ser-querido-cuando-visite-doctor-consejos-rapidos'
# 							'consigue-apoyo-si-eres-cuidador'
# 							'consumo-alcohol-iniciar-conversacion'
# 							'depresion-iniciar-conversacion'
# 							'duerme-lo-suficiente'
# 							'habla-tu-doctor-consumo-indebido-drogas'
# 							'habla-tus-hijos-tabaco-alcohol-drogas'
# 							'pide-haga-tus-hijos-prueba-deteccion-ansiedad'
# 							'pide-hagan-tus-hijos-adolescentes-prueba-detectar-depresion'
# 						'salud-sexual'
# 							'habla-tus-hijos-sexo-relaciones-saludables'
# 							'selecciona-anticonceptivo-adecuado'
# 			'healthypeople'
# 				'priority-areas'
# 					'social-determinants-health'
# 						'literature-summaries'
# 							'access-foods-support-healthy-dietary-patterns'
# 							'access-health-services'
# 							'access-primary-care'
# 							'civic-participation'
# 							'crime-and-violence'
# 							'discrimination'
# 							'early-childhood-development-and-education'
# 							'employment'
# 							'enrollment-higher-education'
# 							'environmental-conditions'
# 							'food-insecurity'
# 							'health-literacy'
# 							'high-school-graduation'
# 							'housing-instability'
# 							'incarceration'
# 							'language-and-literacy'
# 							'poverty'
# 							'quality-housing'
# 							'social-cohesion'
# 			'moveyourway'
# 				'stories'
# 					'cheryl'
# 					'jeff'
# 					'john-patty'
# 					'joni'
# 					'nikia'
# 					'rodriguez-family'
# 				'widget'
# 			'myhealthfinder'
# 				'doctor-visits'
# 					'doctor-visits'
# 						'find-and-access-preventive-services'
# 					'regular-checkups'
# 						'choosing-doctor-quick-tips'
# 						'get-your-medicare-wellness-visit-every-year'
# 						'make-most-your-babys-visit-doctor-ages-0-11-months'
# 						'make-most-your-childs-visit-doctor-ages-1-4-years'
# 						'make-most-your-childs-visit-doctor-ages-11-14-years'
# 						'make-most-your-childs-visit-doctor-ages-5-10-years'
# 						'make-most-your-teens-visit-doctor-ages-15-17-years'
# 						'men-take-charge-your-health'
# 						'oral-health-older-adults-quick-tips'
# 						'take-care-your-childs-teeth'
# 					'screening-tests'
# 						'get-bone-density-test'
# 						'get-screened'
# 						'get-screened-cervical-cancer'
# 						'get-screened-colorectal-cancer'
# 						'get-your-blood-pressure-checked'
# 						'get-your-childs-vision-checked'
# 						'get-your-cholesterol-checked'
# 						'talk-your-doctor-about-anxiety'
# 						'talk-your-doctor-about-depression'
# 						'testing-latent-tuberculosis-questions-doctor'
# 					'talking-doctor'
# 						'colorectal-cancer-screening-questions-doctor'
# 						'genetic-testing-learn-about-your-risk-breast-and-ovarian-cancer-questions-doctor'
# 						'gestational-diabetes-screening-questions-doctor'
# 						'hepatitis-c-screening-questions-doctor'
# 						'lung-cancer-screening-questions-doctor'
# 						'mammograms-questions-doctor'
# 						'medicines-prevent-heart-attack-and-stroke-questions-doctor'
# 						'preventing-osteoporosis-questions-doctor'
# 						'preventing-preeclampsia-questions-doctor'
# 						'preventing-type-2-diabetes-questions-doctor'
# 						'take-charge-your-health-care'
# 					'vaccines-shots'
# 						'get-vaccines-protect-your-health-adults-age-50-years-or-older'
# 						'get-vaccines-protect-your-health-adults-ages-19-49-years'
# 						'get-your-child-hpv-vaccine'
# 						'get-your-childs-vaccines-schedule'
# 						'get-your-pre-teens-vaccines-schedule'
# 						'protect-yourself-seasonal-flu'
# 				'health-conditions'
# 					'cancer'
# 						'colorectal-cancer-screening-conversation-starters'
# 						'get-screened-breast-cancer'
# 						'prostate-cancer-screening-questions-doctor'
# 						'quitting-smoking-conversation-starters'
# 						'take-steps-prevent-skin-cancer'
# 						'talk-doctor-if-breast-or-ovarian-cancer-runs-your-family'
# 					'diabetes'
# 						'aim-healthy-weight'
# 						'eat-healthy'
# 						'get-active'
# 						'healthy-eating-conversation-starters'
# 						'help-loved-one-get-more-active-quick-tips'
# 						'losing-weight-conversation-starters'
# 						'quit-smoking'
# 						'take-steps-prevent-type-2-diabetes'
# 					'heart-health'
# 						'drink-alcohol-only-moderation'
# 						'eat-less-sodium-quick-tips'
# 						'heart-health-conversation-starters'
# 						'heart-healthy-foods-shopping-list'
# 						'keep-your-heart-healthy'
# 						'lower-sodium-foods-shopping-list'
# 						'lower-your-risk-stroke'
# 						'manage-stress'
# 						'talk-your-doctor-about-abdominal-aortic-aneurysm'
# 						'talk-your-doctor-about-taking-aspirin-prevent-disease'
# 					'hiv-and-other-stds'
# 						'get-tested-chlamydia-and-gonorrhea'
# 						'get-tested-hiv'
# 						'hiv-testing-questions-doctor'
# 						'protect-yourself-hepatitis-b'
# 						'sti-testing-conversation-starters'
# 						'talk-your-teen-about-preventing-stis'
# 						'testing-syphilis-questions-doctor'
# 					'obesity'
# 						'help-your-child-stay-healthy-weight'
# 						'losing-weight-questions-doctor'
# 						'stay-active-disability-quick-tips'
# 						'stay-active-you-get-older-quick-tips'
# 				'healthy-living'
# 					'mental-health-and-relationships'
# 						'alcohol-use-conversation-starters'
# 						'anxiety-conversation-starters'
# 						'depression-conversation-starters'
# 						'drug-misuse-conversation-starters'
# 						'get-enough-sleep'
# 						'get-support-if-youre-caregiver'
# 						'get-your-child-screened-anxiety'
# 						'get-your-teen-screened-depression'
# 						'support-loved-one-doctor-quick-tips'
# 						'talk-your-doctor-about-drug-misuse'
# 						'talk-your-kids-about-tobacco-alcohol-and-drugs'
# 						'watch-warning-signs-relationship-violence'
# 					'nutrition'
# 						'calcium-shopping-list'
# 						'get-enough-calcium'
# 						'healthy-snacks-quick-tips-parents'
# 					'physical-activity'
# 						'protect-your-health-you-grow-older'
# 					'safety'
# 						'lower-your-risk-falling'
# 						'prevent-back-pain'
# 						'prevent-infections-when-you-get-medical-care'
# 						'preventing-falls-conversation-starters'
# 						'use-medicines-safely'
# 					'sexual-health'
# 						'choose-right-birth-control'
# 						'get-your-well-woman-visit-every-year'
# 						'talk-your-kids-about-sex-and-healthy-relationships'
# 				'pregnancy'
# 					'doctor-and-midwife-visits'
# 						'breastfeed-your-baby'
# 						'have-healthy-pregnancy'
# 						'talk-your-doctor-about-newborn-screening'
# 					'nutrition-and-physical-activity'
# 						'eat-healthy-during-pregnancy-quick-tips'
# 						'eat-healthy-while-breastfeeding-quick-tips'
# 						'stay-active-during-pregnancy-quick-tips'
# 				'topics'
# 					'everyday-healthy-living'
# 						'nutrition'
# 							'get-enough-folic-acid'
# 			'news'
# 				'category'
# 					'national-health-observances'
# 						'nho-criteria'
# 			'node'
# 				'30768'
# 				'399'
# 			'our-work'
# 				'national-health-initiatives'
# 					'health-literacy'
# 						'consumer-health-content'
# 							'free-web-content'
# 								'apis-developers'
# 									'api-content'
# 									'api-documentation'
# 									'how-use-api'
# 									'terms-use'
# 								'health-widgets-badges'
# 							'myhealthfinder'
# 								'herramientas-promocion-socios-campana-cuidese-carino'
# 								'take-good-care-partner-promotion-toolkit'
# 						'resources'
# 							'national-health-information-center'
# 								'organization'
# 					'healthy-aging'
# 						'about-healthy-aging'
# 						'healthy-aging-resources'
# 						'healthy-people-2030-and-older-adults'
# 						'social-determinants-health-and-older-adults'
# 					'healthy-people'
# 						'about-healthy-people'
# 							'history-healthy-people'
# 						'healthy-people-2020'
# 							'assessing-healthy-people-2020'
# 							'healthy-people-2020-law-and-health-policy'
# 								'applying-law-and-policy-solutions-public-health-challenges-coming-decade'
# 								'comprehensive-approach-preventing-suicide-role-law-and-policy-and-social-determinants-health'
# 								'disability-and-health'
# 									'law-and-health-policy-how-federal-legislation-addresses-needs-people-disabilities'
# 								'exploring-evidence-based-legal-and-policy-strategies-prevent-fatal-injuries-and-violence'
# 								'how-legal-and-policy-levers-can-amplify-efforts-reach-healthy-people-goals'
# 								'maternal-infant-and-child-health'
# 								'nutrition-and-weight-status'
# 								'oral-health'
# 									'law-and-health-policy-oral-health-graphics'
# 								'role-law-and-policy-achieving-health-equity-and-attaining-our-healthy-people-objectives'
# 								'role-law-and-policy-addressing-healthcare-associated-infections'
# 								'substance-abuse'
# 									'substance-abuse-policy-graphics'
# 							'secretarys-advisory-committee-2020'
# 						'healthy-people-2030'
# 							'federal-interagency-workgroup'
# 							'promoting-healthy-people-2030'
# 							'questions-answers'
# 							'secretarys-advisory-committee-2030'
# 								'committee-members'
# 								'secretarys-advisory-committee-2030-committee-reports-and-meetings'
# 									'10th-meeting-agenda'
# 									'11th-meeting-agenda'
# 									'12th-meeting-agenda'
# 									'13th-meeting-agenda'
# 									'14th-meeting-agenda'
# 									'15th-meeting-agenda'
# 									'2nd-meeting-agenda'
# 									'3rd-meeting-agenda'
# 									'4th-meeting-agenda'
# 									'5th-meeting-agenda'
# 									'6th-meeting-agenda'
# 									'7th-meeting-agenda'
# 									'8th-meeting-agenda'
# 									'9th-meeting-agenda'
# 									'inaugural-meeting-agenda'
# 				'nutrition-physical-activity'
# 					'dietary-guidelines'
# 						'current-dietary-guidelines'
# 						'dietary-reference-intakes'
# 							'applying-dietary-reference-intakes-professional-settings'
# 							'dietary-reference-intakes-development'
# 							'maintaining-dietary-reference-intakes'
# 							'review-macronutrients-and-energy'
# 						'previous-dietary-guidelines'
# 							'2015'
# 								'advisory-report'
# 									'appendix-e-2'
# 										'appendix-e-213'
# 											'appendix-e-213'
# 										'appendix-e-215'
# 										'appendix-e-216'
# 										'appendix-e-217'
# 										'appendix-e-218'
# 										'appendix-e-219'
# 										'appendix-e-220'
# 										'appendix-e-221'
# 										'appendix-e-222'
# 										'appendix-e-223'
# 										'appendix-e-224'
# 										'appendix-e-225'
# 										'appendix-e-226'
# 										'appendix-e-227'
# 										'appendix-e-228'
# 										'appendix-e-229a'
# 										'appendix-e-229b'
# 										'appendix-e-230'
# 										'appendix-e-231'
# 										'appendix-e-232'
# 										'appendix-e-233a'
# 										'appendix-e-233b'
# 										'appendix-e-234'
# 										'appendix-e-235'
# 										'appendix-e-236'
# 										'appendix-e-237'
# 										'appendix-e-238'
# 										'appendix-e-239a'
# 										'appendix-e-240'
# 										'appendix-e-241'
# 										'appendix-e-242'
# 										'appendix-e-243'
# 										'appendix-e-244'
# 										'appendix-e-245'
# 										'appendix-e-246'
# 										'appendix-e-247'
# 										'appendix-e-248'
# 										'appendix-e-249'
# 									'appendix-e-3'
# 										'appendix-e-31-adequacy-usda-food-patterns'
# 										'appendix-e-31a1'
# 										'appendix-e-31a2'
# 										'appendix-e-31a3'
# 										'appendix-e-31a4'
# 										'appendix-e-31a5'
# 										'appendix-e-31a6'
# 										'appendix-e-31a7'
# 										'appendix-e-32'
# 										'appendix-e-33'
# 										'appendix-e-34'
# 										'appendix-e-35'
# 										'appendix-e-36'
# 											'appendix-e-36a1page-3-nutrient-levels-usda-food-patterns-milk-group-removed-compared'
# 										'appendix-e-37'
# 										'appendix-e-37a1'
# 										'appendix-e-37a2'
# 										'appendix-e-37b1'
# 										'appendix-e-37b2'
# 										'appendix-e-37c1'
# 										'appendix-e-37c2'
# 										'e3-6-a1-p1'
# 										'e3-6-a1-p2'
# 									'data-table-13'
# 									'public-comments'
# 										'public-comments-scientific-report-2015-dietary-guidelines-advisory-committee'
# 										'read-archived-comments'
# 								'eat-healthy-be-active-community-workshops'
# 									'workshop-4-transcript'
# 								'tools-resources'
# 									'eat-healthy-be-active-community-workshops'
# 										'transcripcion-video-1'
# 										'transcripcion-video-2'
# 										'transcripcion-video-3'
# 										'transcripcion-video-4'
# 										'transcripcion-video-5'
# 										'workshop-1-transcript'
# 										'workshop-2-transcript'
# 										'workshop-3-transcript'
# 										'workshop-5-transcript'
# 					'food-medicine'
# 						'framing-language-and-principles'
# 						'hhs-food-medicine-summit'
# 					'move-your-way-community-resources'
# 						'campaign-materials'
# 							'materials-adults'
# 							'materials-during-and-after-pregnancy'
# 							'materials-health-care-providers'
# 							'materials-kids-and-teens'
# 							'materials-older-adults'
# 							'materials-parents'
# 						'community-playbook'
# 							'about-playbook'
# 							'phase-1-planning-strategy-development'
# 							'phase-2-implementation-evaluation'
# 							'resources'
# 						'partner-promotion-toolkit'
# 						'toolkit-schools'
# 					'national-youth-sports-strategy'
# 						'about-national-youth-sports-strategy'
# 							'top-10-things-know-about-national-youth-sports-strategy'
# 						'nyss-champions'
# 							'become-nyss-champion'
# 								'submission-confirmation'
# 						'partner-promotion-toolkit'
# 						'questions-answers'
# 					'physical-activity-guidelines'
# 						'about-physical-activity-guidelines'
# 							'questions-answers'
# 						'current-guidelines'
# 							'advisory-committee'
# 								'public-meetings'
# 									'meeting-1'
# 										'meeting-1-agenda'
# 									'meeting-2'
# 										'meeting-2-agenda'
# 									'meeting-3'
# 										'meeting-3-agenda'
# 									'meeting-4'
# 										'meeting-4-agenda'
# 									'meeting-5'
# 										'meeting-5-agenda'
# 								'resources'
# 									'charge-2018-physical-activity-guidelines-advisory-committee'
# 							'federal-partners-initiatives'
# 							'media-resources'
# 							'midcourse-report'
# 								'10-things-know'
# 								'questions-and-answers'
# 							'scientific-report'
# 								'supplementary-material'
# 							'top-10-things-know'
# 						'previous-guidelines'
# 							'2008-physical-activity-guidelines'
# 								'advisory-report'
# 							'2013-midcourse-report'
# 								'questions-answers'
# 					'presidents-council'
# 						'about-pcsfn'
# 							'science-board'
# 								'elevate-health'
# 						'council-meetings'
# 							'pcsfn-2018-annual-council-meeting-agenda'
# 							'pcsfn-2019-annual-council-meeting-agenda'
# 							'pcsfn-2020-annual-council-meeting-agenda'
# 							'pcsfn-2023-annual-council-meeting-agenda'
# 						'programs-awards'
# 							'presidential-youth-fitness-program'
# 				'pcsfn'
# 					'council-members'
# 						'allison-otoole'
# 						'ayesha-curry'
# 						'barbie-izquierdo'
# 						'ben-jacobs'
# 						'billy-shore'
# 						'chaunte-lowe'
# 						'chloe-kim'
# 						'dariush-mozaffarian'
# 						'elana-meyers-taylor'
# 						'elena-delle-donne'
# 						'j-nadine-gracia'
# 						'jon-feinman'
# 						'jose-andres'
# 						'jose-garces'
# 						'kahina-haynes'
# 						'kim-ng'
# 						'laura-ricketts'
# 						'maribel-campos-rivera'
# 						'martin-e-ingelsby'
# 						'meg-ham'
# 						'melissa-stockwell'
# 						'michael-solomonov'
# 						'oluwaferanmi-oyedeji-okanlami'
# 						'rayhaan-merani'
# 						'ryan-howard'
# 						'stefany-shaheen'
# 						'stephen-curry'
# 						'tamika-catchings'
# 						'tina-flournoy'
# 						'viviana-martinez-bianchi'
# 				'your-health'
# 			'pcsfn'
# 				'about-pcsfn'
# 					'executive-order'
# 					'media-library'
# 					'national-fitness-foundation'
# 				'council-meetings'
# 					'pcsfn-2023-virtual-council-meeting-agenda'
# 				'council-members'
# 				'council-members-action'
# 					'hot-three-sisters-succotash'
# 					'turkey-or-veggie-tacos'
# 					'wild-rice-pilaf'
# 				'history-council'
# 				'professional-sports-partnership'
# 				'programs-awards'
# 					'pcsfn-community-leadership-award'
# 					'pcsfn-hero-award'
# 					'pcsfn-lifetime-impact-award'
# 				'tribal-resource-hub'
# 					'data-and-research'
# 					'education-and-outreach'
# 					'health-and-community-well-being'
# 					'tribal-elders'
# 					'tribal-individuals-families-and-communities'
# 					'tribal-schools-childcare-programs-and-early-learning-providers'
# 			'test-page'

# %%
type(root.children[0].children[0])
# Out:
# __main__.URLNode

# %%
type(root)
# Out:
# __main__.URLNode

# %%
big_root = root_to_bigtree(big_root)

# %%
graph = tree_to_dot(big_root, node_colour = "gold")
graph.write_png("/sitemaptree.png")
# Out:
# <MagicMock name='mock.Dot().write_png()' id='2031635453264'>

# %%
import pandas as pd

df = pd.DataFrame(tree_to_dataframe(big_root))


with open("subdir_map.csv", 'w') as outfile:
    outfile.write(df.to_csv(sep=';', header=False, index=False))
